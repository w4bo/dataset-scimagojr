# %%
import os
import pandas as pd

# Specify the path to the data folder
data_folder = 'data'

# Get a list of all CSV files in the data folder
csv_files = [file for file in os.listdir(data_folder) if file.endswith('.csv')]

# Initialize an empty list to store the dataframes
dfs = []

# Read each CSV file and append its dataframe to the list
for file in csv_files:
    file_path = os.path.join(data_folder, file)
    df = pd.read_csv(file_path, delimiter=';')
    dfs.append(df)

# Merge all dataframes into a single dataframe
merged_df = pd.concat(dfs)

# Drop duplicated values
merged_df = merged_df.drop_duplicates()

# Print the merged dataframe
merged_df
# Out:
#      Rank     Sourceid                                              Title  \
# 0       1  19300156903         Foundations and Trends in Machine Learning
# 1       2        23080                              Advances in Computers
# 2       3        18902   IEEE Journal on Selected Areas in Communications
# 3       4  19600166419        Foundations and Trends in Signal Processing
# 4       5  21100831443                      Nature Biomedical Engineering
# ..    ...          ...                                                ...
# 321   322        26645              Concurrent Systems Engineering Series
# 322   323  21100318403  Journal of the Institute of Image Electronics ...
# 323   324   7000153240  Computational Intelligence and Neuroscience (d...
# 324   325  21100400012  Proceedings of International Conference of the...
# 325   326  21100925870  World Journal on Educational Technology: Curre...
#
#             Type                Issn     SJR SJR Best Quartile  H index  \
# ...

# %%
merged_df[merged_df["Title"].str.contains("Agricult")]
# Out:
#       Rank     Sourceid                                              Title  \
# 204    205        30441           Computers and Electronics in Agriculture
# 309    310  21101042196             Artificial Intelligence in Agriculture
# 450    451  21100804573              Information Processing in Agriculture
# 1290  1291  21100207605  International Journal of Agricultural and Envi...
# 34      35  21101042196             Artificial Intelligence in Agriculture
#
#          Type                Issn    SJR SJR Best Quartile  H index  \
# 204   journal            01681699  1,587                Q1      149
# 309   journal            25897217  1,202                Q1       11
# 450   journal            22143173  0,963                Q1       45
# 1290  journal  19473206, 19473192  0,301                Q3       17
# 34    journal            25897217  1,202               NaN       11
#
#       Total Docs. (2022)  Total Docs. (3years)  ...  Citable Docs. (3years)  \
# ...

# %%
keyword = "Agricultur"
agriculture_df = merged_df[merged_df["Title"].str.contains(keyword) | 
                           merged_df["Areas"].str.contains(keyword) | 
                           merged_df["Categories"].str.contains(keyword)]

agriculture_df.to_csv("agriculture_data2.csv", index=False)
agriculture_df
# Out:
#       Rank     Sourceid                                              Title  \
# 7        8   4700152228                          Molecular Systems Biology
# 151    152   4000151810                         PLoS Computational Biology
# 157    158        13017                            Physics of Life Reviews
# 164    165  19700188321  Database : the journal of biological databases...
# 183    184  21100850723                                           mSystems
# 204    205        30441           Computers and Electronics in Agriculture
# 309    310  21101042196             Artificial Intelligence in Agriculture
# 450    451  21100804573              Information Processing in Agriculture
# 476    477   3100147401                             Ecological Informatics
# 561    562  21100810702                                Animal Biotelemetry
# 628    629        13560                              Ecological Psychology
# ...
